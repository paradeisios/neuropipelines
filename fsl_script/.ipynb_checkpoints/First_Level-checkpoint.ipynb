# %%
from nipype import Node, Workflow, IdentityInterface, Function, MapNode,SelectFiles, DataSink
from nipype.interfaces import fsl
from nipype.algorithms.modelgen import SpecifyModel
import numpy as np
import os

# %%
def gather_subject_info(tsv_filename):
    
    import pandas as pd
    from nipype.interfaces.base import Bunch
    
    trialinfo = pd.read_table(tsv_filename)

    conditions = []
    onsets = []
    durations = []

    for group in trialinfo.groupby('Stimulus'):
        conditions.append(group[0])
        onsets.append(list(group[1].onset)) 
        durations.append(list(group[1].duration))

    subject_info = Bunch(conditions=conditions,
                          onsets=onsets,
                          durations=durations)

    return subject_info

# %%
data   = "/home/paradeisios/Desktop/nipype_output/preprocessing/"
output = "/home/paradeisios/Desktop/nipype_output/first_level/"

num_of_subjects = 1
num_of_runs = 2

subject_list = ["{:02d}".format(i) for i in range(1,num_of_subjects+1)]

TR = 2.5


cont1 = ['Congruent',   'T', ['congruent', 'incongruent'], [1, 0]]
cont2 = ['Incongruent', 'T', ['incongruent', 'congruent'], [0, 1]]
cont3 = ['Congruent > Incongruent', 'T', ['congruent', 'incongruent'], [1, -1]]
cont4 = ['Incongruent > Congruent', 'T', ['incongruent', 'congruent'], [1, -1,]]
contrasts = [cont1,cont2,cont3,cont4]

# %%
infosource = Node(IdentityInterface(fields=["subject_list"]), name="infosource")
infosource.iterables = [('subject_list', subject_list)]

# %%
templates = {"func":        "{subject_list}/smooth/{subject_list}/smooth_run_*/sub-{subject_list}_task-flanker_run-*_bold_maths_roi_mcf_warp_smooth.nii.gz",
             "real_params":  "{subject_list}/realign/{subject_list}/realign_*/sub-{subject_list}_task-flanker_run-*_bold_maths_roi_mcf.nii.gz.par",
             "conditions" : "{subject_list}/conditions/sub-{subject_list}_task-flanker_run-*_events.tsv"}

selectfiles = Node(SelectFiles(templates),name="selectfiles")
selectfiles.inputs.base_directory = data

# %%
substitutions = []
substitutions += [("_subject_list_{:02d}".format(i), "{:02d}".format(i)) for i in range(1,num_of_subjects+1)]
substitutions += [("_modelestimate{:d}".format(i), "modelestimate_run_{:d}".format(i+1)) for i in range(0,num_of_runs)]
substitutions += [("_modelgen{:d}".format(i), "modelgen_run_{:d}".format(i+1)) for i in range(0,num_of_runs)]
substitutions += [("_level1design{:d}".format(i), "level1design_run_{:d}".format(i+1)) for i in range(0,num_of_runs)]

datasink = Node(DataSink(base_directory=output),name="datasink")
datasink.inputs.substitutions = substitutions
datasink.output = output

# %%
getsubjectinfo = MapNode(Function(input_names=["tsv_filename"],output_names=['subject_info'],
                                  function=gather_subject_info),
                                  iterfield = ["tsv_filename"],
                                  name='getsubjectinfo')


specify_model = MapNode(SpecifyModel(),name="specify_model",
                        iterfield=["functional_runs","subject_info","realignment_parameters"])
specify_model.inputs.input_units = 'secs'
specify_model.inputs.time_repetition = TR
specify_model.inputs.high_pass_filter_cutoff = 128.              




level1design = MapNode(fsl.Level1Design(), name="level1design",iterfield = ["session_info"])# make the model
level1design.inputs.bases = {'dgamma':{'derivs': False}}
level1design.inputs.interscan_interval = TR
level1design.inputs.model_serial_correlations=True
level1design.inputs.contrasts=contrasts

modelgen = MapNode(fsl.FEATModel(),name='modelgen',iterfield = ["fsf_file","ev_files"]) # transform to fsl model

modelestimate = MapNode(fsl.FILMGLS(), name='modelestimate',iterfield=["in_file","design_file","tcon_file"]) #run the model
modelestimate.inputs.smooth_autocorr=True 
modelestimate.inputs.threshold = 10

# %%
first_level_analysis = Workflow(name="first_level_analysis")

first_level_analysis.connect(infosource, "subject_list", selectfiles, "subject_list")
first_level_analysis.connect(selectfiles, "conditions", getsubjectinfo, "tsv_filename")

first_level_analysis.connect(selectfiles, "func", specify_model, "functional_runs")
first_level_analysis.connect(selectfiles, "real_params", specify_model, "realignment_parameters")
first_level_analysis.connect(getsubjectinfo,"subject_info",specify_model,"subject_info")

first_level_analysis.connect(specify_model,"session_info",level1design,"session_info")

first_level_analysis.connect(level1design,"fsf_files",modelgen,"fsf_file")
first_level_analysis.connect(level1design,"ev_files",modelgen,"ev_files")

first_level_analysis.connect(selectfiles, "func", modelestimate, "in_file")
first_level_analysis.connect(modelgen,"design_file",modelestimate,"design_file")
first_level_analysis.connect(modelgen,"con_file",modelestimate,"tcon_file")

first_level_analysis.connect(level1design,"fsf_files",datasink,"level1design.@fsf_files")
first_level_analysis.connect(level1design,"ev_files",datasink,"level1design.@ev_files")

first_level_analysis.connect(modelgen,"design_file",datasink,"model.@design_file")
first_level_analysis.connect(modelgen,"design_cov",datasink,"model.@design_cov")
first_level_analysis.connect(modelgen,"design_image",datasink,"model.@design_matrix")

first_level_analysis.connect(modelestimate,"copes",datasink,"modelestimate.@copes")
first_level_analysis.connect(modelestimate,"varcopes",datasink,"modelestimate.@varcopes")
first_level_analysis.connect(modelestimate,"tstats",datasink,"modelestimate.@tstats")
first_level_analysis.connect(modelestimate,"zstats",datasink,"modelestimate.@zstats")
first_level_analysis.connect(modelestimate,"dof_file",datasink,"modelestimate.@dof_file")

# %%
first_level_analysis.write_graph(graph2use='flat', format='png', simple_form=True,
                              dotfilename= os.path.join(output,"first_level_analysis_workflow.dot"))
# Out:
# 210807-00:02:50,851 nipype.workflow INFO:
# 	 Generated workflow graph: /home/paradeisios/Desktop/nipype_output/first_level/first_level_analysis_workflow.png (graph2use=flat, simple_form=True).
# '/home/paradeisios/Desktop/nipype_output/first_level/first_level_analysis_workflow.png'

# %%
first_level_analysis.run(plugin='MultiProc', plugin_args={'n_procs' : 1})
# Out:
# 210807-00:02:50,908 nipype.workflow INFO:
# 	 Workflow first_level_analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 210807-00:02:50,937 nipype.workflow INFO:
# 	 Running in parallel.
# 210807-00:02:50,940 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:02:51,23 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp985x02_n/first_level_analysis/_subject_list_01/selectfiles".
# 210807-00:02:51,38 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210807-00:02:51,50 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210807-00:02:52,945 nipype.workflow INFO:
# 	 [Job 0] Completed (first_level_analysis.selectfiles).
# 210807-00:02:52,953 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:02:54,947 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:02:54,994 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmpok3qmb8b/first_level_analysis/_subject_list_01/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210807-00:02:55,10 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo0" ("nipype.interfaces.utility.wrappers.Function")
# 210807-00:02:55,444 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo0".
# 210807-00:02:56,947 nipype.workflow INFO:
# 	 [Job 7] Completed (_getsubjectinfo0).
# 210807-00:02:56,949 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:02:57,2 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmpok3qmb8b/first_level_analysis/_subject_list_01/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210807-00:02:57,8 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo1" ("nipype.interfaces.utility.wrappers.Function")
# 210807-00:02:57,19 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo1".
# 210807-00:02:58,948 nipype.workflow INFO:
# 	 [Job 8] Completed (_getsubjectinfo1).
# 210807-00:02:58,950 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:02:59,11 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.getsubjectinfo" in "/tmp/tmpok3qmb8b/first_level_analysis/_subject_list_01/getsubjectinfo".
# 210807-00:02:59,17 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmpok3qmb8b/first_level_analysis/_subject_list_01/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210807-00:02:59,19 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo0" - collecting precomputed outputs
# 210807-00:02:59,21 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo0" found cached.
# 210807-00:02:59,31 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmpok3qmb8b/first_level_analysis/_subject_list_01/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210807-00:02:59,33 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo1" - collecting precomputed outputs
# 210807-00:02:59,34 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo1" found cached.
# 210807-00:02:59,39 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.getsubjectinfo".
# 210807-00:03:00,951 nipype.workflow INFO:
# 	 [Job 1] Completed (first_level_analysis.getsubjectinfo).
# 210807-00:03:00,956 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:02,953 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:03,11 nipype.workflow INFO:
# 	 [Node] Setting-up "_specify_model0" in "/tmp/tmpflqc6frj/first_level_analysis/_subject_list_01/specify_model/mapflow/_specify_model0".
# 210807-00:03:03,26 nipype.workflow INFO:
# 	 [Node] Running "_specify_model0" ("nipype.algorithms.modelgen.SpecifyModel")
# 210807-00:03:03,42 nipype.workflow INFO:
# 	 [Node] Finished "_specify_model0".
# 210807-00:03:04,954 nipype.workflow INFO:
# 	 [Job 9] Completed (_specify_model0).
# 210807-00:03:04,958 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:05,10 nipype.workflow INFO:
# 	 [Node] Setting-up "_specify_model1" in "/tmp/tmpflqc6frj/first_level_analysis/_subject_list_01/specify_model/mapflow/_specify_model1".
# 210807-00:03:05,18 nipype.workflow INFO:
# 	 [Node] Running "_specify_model1" ("nipype.algorithms.modelgen.SpecifyModel")
# 210807-00:03:05,55 nipype.workflow INFO:
# 	 [Node] Finished "_specify_model1".
# 210807-00:03:06,955 nipype.workflow INFO:
# 	 [Job 10] Completed (_specify_model1).
# 210807-00:03:06,957 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:07,15 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.specify_model" in "/tmp/tmpflqc6frj/first_level_analysis/_subject_list_01/specify_model".
# 210807-00:03:07,27 nipype.workflow INFO:
# 	 [Node] Setting-up "_specify_model0" in "/tmp/tmpflqc6frj/first_level_analysis/_subject_list_01/specify_model/mapflow/_specify_model0".
# 210807-00:03:07,32 nipype.workflow INFO:
# 	 [Node] Cached "_specify_model0" - collecting precomputed outputs
# 210807-00:03:07,36 nipype.workflow INFO:
# 	 [Node] "_specify_model0" found cached.
# 210807-00:03:07,41 nipype.workflow INFO:
# 	 [Node] Setting-up "_specify_model1" in "/tmp/tmpflqc6frj/first_level_analysis/_subject_list_01/specify_model/mapflow/_specify_model1".
# 210807-00:03:07,46 nipype.workflow INFO:
# 	 [Node] Cached "_specify_model1" - collecting precomputed outputs
# 210807-00:03:07,49 nipype.workflow INFO:
# 	 [Node] "_specify_model1" found cached.
# 210807-00:03:07,62 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.specify_model".
# 210807-00:03:08,957 nipype.workflow INFO:
# 	 [Job 2] Completed (first_level_analysis.specify_model).
# 210807-00:03:08,959 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:10,960 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:11,44 nipype.workflow INFO:
# 	 [Node] Setting-up "_level1design0" in "/tmp/tmpbc4fd2zh/first_level_analysis/_subject_list_01/level1design/mapflow/_level1design0".
# 210807-00:03:11,70 nipype.workflow INFO:
# 	 [Node] Running "_level1design0" ("nipype.interfaces.fsl.model.Level1Design")
# 210807-00:03:11,100 nipype.workflow INFO:
# 	 [Node] Finished "_level1design0".
# 210807-00:03:12,961 nipype.workflow INFO:
# 	 [Job 11] Completed (_level1design0).
# 210807-00:03:12,963 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:13,22 nipype.workflow INFO:
# 	 [Node] Setting-up "_level1design1" in "/tmp/tmpbc4fd2zh/first_level_analysis/_subject_list_01/level1design/mapflow/_level1design1".
# 210807-00:03:13,41 nipype.workflow INFO:
# 	 [Node] Running "_level1design1" ("nipype.interfaces.fsl.model.Level1Design")
# 210807-00:03:13,58 nipype.workflow INFO:
# 	 [Node] Finished "_level1design1".
# 210807-00:03:14,964 nipype.workflow INFO:
# 	 [Job 12] Completed (_level1design1).
# 210807-00:03:14,967 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:15,58 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.level1design" in "/tmp/tmpbc4fd2zh/first_level_analysis/_subject_list_01/level1design".
# 210807-00:03:15,113 nipype.workflow INFO:
# 	 [Node] Setting-up "_level1design0" in "/tmp/tmpbc4fd2zh/first_level_analysis/_subject_list_01/level1design/mapflow/_level1design0".
# 210807-00:03:15,127 nipype.workflow INFO:
# 	 [Node] Cached "_level1design0" - collecting precomputed outputs
# 210807-00:03:15,132 nipype.workflow INFO:
# 	 [Node] "_level1design0" found cached.
# 210807-00:03:15,135 nipype.workflow INFO:
# 	 [Node] Setting-up "_level1design1" in "/tmp/tmpbc4fd2zh/first_level_analysis/_subject_list_01/level1design/mapflow/_level1design1".
# 210807-00:03:15,159 nipype.workflow INFO:
# 	 [Node] Cached "_level1design1" - collecting precomputed outputs
# 210807-00:03:15,161 nipype.workflow INFO:
# 	 [Node] "_level1design1" found cached.
# 210807-00:03:15,180 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.level1design".
# 210807-00:03:16,965 nipype.workflow INFO:
# 	 [Job 3] Completed (first_level_analysis.level1design).
# 210807-00:03:16,968 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:18,969 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:19,23 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen0" in "/tmp/tmp0uwqick7/first_level_analysis/_subject_list_01/modelgen/mapflow/_modelgen0".
# 210807-00:03:19,29 nipype.workflow INFO:
# 	 [Node] Running "_modelgen0" ("nipype.interfaces.fsl.model.FEATModel"), a CommandLine Interface with command:
# feat_model run0
# 210807-00:03:19,718 nipype.workflow INFO:
# 	 [Node] Finished "_modelgen0".
# 210807-00:03:20,970 nipype.workflow INFO:
# 	 [Job 13] Completed (_modelgen0).
# 210807-00:03:20,974 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:21,36 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen1" in "/tmp/tmp0uwqick7/first_level_analysis/_subject_list_01/modelgen/mapflow/_modelgen1".
# 210807-00:03:21,43 nipype.workflow INFO:
# 	 [Node] Running "_modelgen1" ("nipype.interfaces.fsl.model.FEATModel"), a CommandLine Interface with command:
# feat_model run0
# 210807-00:03:21,613 nipype.workflow INFO:
# 	 [Node] Finished "_modelgen1".
# 210807-00:03:22,972 nipype.workflow INFO:
# 	 [Job 14] Completed (_modelgen1).
# 210807-00:03:22,976 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:23,23 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.modelgen" in "/tmp/tmp0uwqick7/first_level_analysis/_subject_list_01/modelgen".
# 210807-00:03:23,30 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen0" in "/tmp/tmp0uwqick7/first_level_analysis/_subject_list_01/modelgen/mapflow/_modelgen0".
# 210807-00:03:23,34 nipype.workflow INFO:
# 	 [Node] Cached "_modelgen0" - collecting precomputed outputs
# 210807-00:03:23,35 nipype.workflow INFO:
# 	 [Node] "_modelgen0" found cached.
# 210807-00:03:23,38 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelgen1" in "/tmp/tmp0uwqick7/first_level_analysis/_subject_list_01/modelgen/mapflow/_modelgen1".
# 210807-00:03:23,40 nipype.workflow INFO:
# 	 [Node] Cached "_modelgen1" - collecting precomputed outputs
# 210807-00:03:23,41 nipype.workflow INFO:
# 	 [Node] "_modelgen1" found cached.
# 210807-00:03:23,44 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.modelgen".
# 210807-00:03:24,975 nipype.workflow INFO:
# 	 [Job 4] Completed (first_level_analysis.modelgen).
# 210807-00:03:24,979 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:26,977 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210807-00:03:27,24 nipype.workflow INFO:
# 	 [Node] Setting-up "_modelestimate0" in "/tmp/tmpmgr1tao9/first_level_analysis/_subject_list_01/modelestimate/mapflow/_modelestimate0".
# 210807-00:03:27,28 nipype.workflow INFO:
# 	 [Node] Running "_modelestimate0" ("nipype.interfaces.fsl.model.FILMGLS"), a CommandLine Interface with command:
# film_gls --rn=results --sa --con=/tmp/tmp0uwqick7/first_level_analysis/_subject_list_01/modelgen/mapflow/_modelgen0/run0.con --in=/home/paradeisios/Desktop/nipype_output/preprocessing/01/smooth/01/smooth_run_1/sub-01_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz --pd=/tmp/tmp0uwqick7/first_level_analysis/_subject_list_01/modelgen/mapflow/_modelgen0/run0.mat --thr=10.000000
# 210807-00:03:28,978 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _modelestimate0
