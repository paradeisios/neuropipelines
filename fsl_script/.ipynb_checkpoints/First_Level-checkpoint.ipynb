# %%
from nipype import Node, Workflow, IdentityInterface, Function, MapNode,SelectFiles, DataSink
from nipype.interfaces import fsl
from nipype.algorithms.modelgen import SpecifyModel
import numpy as np
import os

# %%
def gather_subject_info(tsv_filename):
    
    import pandas as pd
    from nipype.interfaces.base import Bunch
    
    trialinfo = pd.read_table(tsv_filename)

    conditions = []
    onsets = []
    durations = []

    for group in trialinfo.groupby('Stimulus'):
        conditions.append(group[0])
        onsets.append(list(group[1].onset)) 
        durations.append(list(group[1].duration))

    subject_info = Bunch(conditions=conditions,
                          onsets=onsets,
                          durations=durations)

    return subject_info

# %%
data   = "/media/paradeisios/UUI/fmri/flanker/output/preprocessing"
output = "/media/paradeisios/UUI/fmri/flanker/output/first_level"
brain_mask = "/home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz"

num_of_subjects = 26
num_of_runs = 2

subject_list = ["{:02d}".format(i) for i in range(1,num_of_subjects+1)]

TR = 2


cont1 = ['Con+',   'T', ['congruent'], [1]]
cont2 = ['Incon+', 'T', ['incongruent'], [1]]
cont3 = ['Con-',   'T', ['congruent'], [-1]]
cont4 = ['Incon-', 'T', ['incongruent'], [-1]]
cont5 = ['Con > Incon', 'T', ['congruent', 'incongruent'], [1, -1]]
cont6 = ['Incon > Con', 'T', ['congruent', 'incongruent'], [-1, 1,]]
contrasts = [cont1,cont2,cont3,cont4,cont5,cont6]

# %%
infosource = Node(IdentityInterface(fields=["subject_list"]), name="infosource")
infosource.iterables = [('subject_list', subject_list)]

# %%
templates = {"func"       : "{subject_list}/smooth/{subject_list}/smooth_run_*/sub-{subject_list}_task-flanker_run-*_bold_maths_roi_mcf_warp_smooth.nii.gz",
             "real_params": "{subject_list}/realign/{subject_list}/realign_*/sub-{subject_list}_task-flanker_run-*_bold_maths_roi_mcf.nii.gz.par",
             "conditions" : "{subject_list}/conditions/sub-{subject_list}_task-flanker_run-*_events.tsv",
             "outliers"   : "{subject_list}/art/{subject_list}/art_run_*/art.sub-{subject_list}_task-flanker_run-*_bold_maths_roi_mcf_outliers.txt"}

selectfiles = Node(SelectFiles(templates),name="selectfiles")
selectfiles.inputs.base_directory = data

# %%
substitutions = []
substitutions += [("_subject_list_{:02d}".format(i), "{:02d}".format(i)) for i in range(1,num_of_subjects+1)]
substitutions += [("_modelestimate{:d}".format(i), "modelestimate_run_{:d}".format(i+1)) for i in range(0,num_of_runs)]
substitutions += [("_modelgen{:d}".format(i), "modelgen_run_{:d}".format(i+1)) for i in range(0,num_of_runs)]
substitutions += [("_level1design{:d}".format(i), "level1design_run_{:d}".format(i+1)) for i in range(0,num_of_runs)]

datasink = Node(DataSink(base_directory=output),name="datasink")
datasink.inputs.substitutions = substitutions
datasink.output = output

# %%
getsubjectinfo = MapNode(Function(input_names=["tsv_filename"],output_names=['subject_info'],
                                  function=gather_subject_info),
                                  iterfield = ["tsv_filename"],
                                  name='getsubjectinfo')

mask_functional = MapNode(fsl.maths.ApplyMask(),name="mask_functional",iterfield=["in_file"])
mask_functional.inputs.mask_file = brain_mask

specify_model = MapNode(SpecifyModel(),name="specify_model",
                        iterfield=["functional_runs","subject_info","outlier_files"])#"realignment_parameters","outlier_files"])
specify_model.inputs.input_units = 'secs'
specify_model.inputs.time_repetition = TR
specify_model.inputs.high_pass_filter_cutoff = 100.              
specify_model.inputs.parameter_source = "FSL"

level1design = MapNode(fsl.Level1Design(), name="level1design",iterfield = ["session_info"])# make the model
level1design.inputs.bases = {'dgamma':{'derivs': True}}
level1design.inputs.interscan_interval = TR
level1design.inputs.model_serial_correlations=True
level1design.inputs.contrasts=contrasts

modelgen = MapNode(fsl.FEATModel(),name='modelgen',iterfield = ["fsf_file","ev_files"]) # transform to fsl model

model_threshold = MapNode(fsl.ImageStats(),name="model_threshold",iterfield=["in_file"])
model_threshold.inputs.op_string = "-P 10"

modelestimate = MapNode(fsl.FILMGLS(), name='modelestimate',iterfield=["in_file","design_file","tcon_file","threshold"]) #run the model
modelestimate.inputs.smooth_autocorr=True 
modelestimate.inputs.mask_size=5

# %%
first_level_analysis = Workflow(name="first_level_analysis")

first_level_analysis.connect(infosource, "subject_list", selectfiles, "subject_list")
first_level_analysis.connect(selectfiles, "conditions", getsubjectinfo, "tsv_filename")


first_level_analysis.connect(selectfiles, "func", mask_functional, "in_file")

#first_level_analysis.connect(selectfiles, "real_params", specify_model, "realignment_parameters")
first_level_analysis.connect(selectfiles, "outliers", specify_model, "outlier_files")
first_level_analysis.connect(getsubjectinfo,"subject_info",specify_model,"subject_info")
first_level_analysis.connect(mask_functional, "out_file", specify_model, "functional_runs")

first_level_analysis.connect(mask_functional, "out_file", model_threshold, "in_file")

first_level_analysis.connect(specify_model,"session_info",level1design,"session_info")

first_level_analysis.connect(level1design,"fsf_files",modelgen,"fsf_file")
first_level_analysis.connect(level1design,"ev_files",modelgen,"ev_files")

first_level_analysis.connect(mask_functional, "out_file", modelestimate, "in_file")
first_level_analysis.connect(model_threshold, "out_stat", modelestimate, "threshold")
first_level_analysis.connect(modelgen,"design_file",modelestimate,"design_file")
first_level_analysis.connect(modelgen,"con_file",modelestimate,"tcon_file")

first_level_analysis.connect(level1design,"fsf_files",datasink,"level1design.@fsf_files")
first_level_analysis.connect(level1design,"ev_files",datasink,"level1design.@ev_files")

first_level_analysis.connect(modelgen,"design_file",datasink,"model.@design_file")
first_level_analysis.connect(modelgen,"design_cov",datasink,"model.@design_cov")
first_level_analysis.connect(modelgen,"design_image",datasink,"model.@design_matrix")

first_level_analysis.connect(modelestimate,"copes",datasink,"modelestimate.@copes")
first_level_analysis.connect(modelestimate,"varcopes",datasink,"modelestimate.@varcopes")
first_level_analysis.connect(modelestimate,"tstats",datasink,"modelestimate.@tstats")
first_level_analysis.connect(modelestimate,"zstats",datasink,"modelestimate.@zstats")
first_level_analysis.connect(modelestimate,"dof_file",datasink,"modelestimate.@dof_file")

# %%
first_level_analysis.write_graph(graph2use='flat', format='png', simple_form=True,
                              dotfilename= os.path.join(output,"first_level_analysis_workflow.dot"))
# Out:
# 210814-22:13:34,296 nipype.workflow INFO:
# 	 Generated workflow graph: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/first_level_analysis_workflow.png (graph2use=flat, simple_form=True).
# '/media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/first_level_analysis_workflow.png'

# %%
first_level_analysis.run(plugin='MultiProc', plugin_args={'n_procs' : 1})
# Out:
# 210814-22:13:34,375 nipype.workflow INFO:
# 	 Workflow first_level_analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 210814-22:13:34,695 nipype.workflow INFO:
# 	 Running in parallel.
# 210814-22:13:34,705 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 26 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:34,789 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmplyxvzpy3/first_level_analysis/_subject_list_26/selectfiles".
# 210814-22:13:34,800 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:34,821 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:36,709 nipype.workflow INFO:
# 	 [Job 0] Completed (first_level_analysis.selectfiles).
# 210814-22:13:36,716 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 27 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:36,811 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp_hw9bujr/first_level_analysis/_subject_list_25/selectfiles".
# 210814-22:13:36,817 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:36,832 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:38,708 nipype.workflow INFO:
# 	 [Job 9] Completed (first_level_analysis.selectfiles).
# 210814-22:13:38,711 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 30 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:38,796 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp0xyvpcm5/first_level_analysis/_subject_list_24/selectfiles".
# 210814-22:13:38,803 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:38,859 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:40,710 nipype.workflow INFO:
# 	 [Job 18] Completed (first_level_analysis.selectfiles).
# 210814-22:13:40,716 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 33 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:40,793 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpkico03s_/first_level_analysis/_subject_list_23/selectfiles".
# 210814-22:13:40,797 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:40,812 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:42,712 nipype.workflow INFO:
# 	 [Job 27] Completed (first_level_analysis.selectfiles).
# 210814-22:13:42,720 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 36 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:42,812 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpkeh0inkx/first_level_analysis/_subject_list_22/selectfiles".
# 210814-22:13:42,818 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:42,834 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:44,715 nipype.workflow INFO:
# 	 [Job 36] Completed (first_level_analysis.selectfiles).
# 210814-22:13:44,724 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:44,807 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpjn54_j9b/first_level_analysis/_subject_list_21/selectfiles".
# 210814-22:13:44,816 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:44,858 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:46,715 nipype.workflow INFO:
# 	 [Job 45] Completed (first_level_analysis.selectfiles).
# 210814-22:13:46,720 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 42 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:46,832 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpihov1g19/first_level_analysis/_subject_list_20/selectfiles".
# 210814-22:13:46,839 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:46,856 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:48,715 nipype.workflow INFO:
# 	 [Job 54] Completed (first_level_analysis.selectfiles).
# 210814-22:13:48,718 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 45 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:48,818 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpvp43r73h/first_level_analysis/_subject_list_19/selectfiles".
# 210814-22:13:48,824 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:48,840 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:50,718 nipype.workflow INFO:
# 	 [Job 63] Completed (first_level_analysis.selectfiles).
# 210814-22:13:50,723 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 48 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:50,795 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp9phleyuc/first_level_analysis/_subject_list_18/selectfiles".
# 210814-22:13:50,799 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:50,846 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:52,718 nipype.workflow INFO:
# 	 [Job 72] Completed (first_level_analysis.selectfiles).
# 210814-22:13:52,724 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 51 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:52,824 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpnr153jkw/first_level_analysis/_subject_list_17/selectfiles".
# 210814-22:13:52,832 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:52,877 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:54,722 nipype.workflow INFO:
# 	 [Job 81] Completed (first_level_analysis.selectfiles).
# 210814-22:13:54,728 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 54 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:54,838 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpvuby5jty/first_level_analysis/_subject_list_16/selectfiles".
# 210814-22:13:54,845 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:54,865 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:56,721 nipype.workflow INFO:
# 	 [Job 90] Completed (first_level_analysis.selectfiles).
# 210814-22:13:56,724 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 57 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:56,847 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp76ajrid8/first_level_analysis/_subject_list_15/selectfiles".
# 210814-22:13:56,857 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:56,880 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:13:58,723 nipype.workflow INFO:
# 	 [Job 99] Completed (first_level_analysis.selectfiles).
# 210814-22:13:58,727 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 60 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:13:58,808 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpiyvmzgw2/first_level_analysis/_subject_list_14/selectfiles".
# 210814-22:13:58,812 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:13:58,834 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:00,725 nipype.workflow INFO:
# 	 [Job 108] Completed (first_level_analysis.selectfiles).
# 210814-22:14:00,731 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 63 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:00,845 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmppsyxzubx/first_level_analysis/_subject_list_13/selectfiles".
# 210814-22:14:00,850 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:00,888 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:02,728 nipype.workflow INFO:
# 	 [Job 117] Completed (first_level_analysis.selectfiles).
# 210814-22:14:02,735 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 66 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:02,840 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpi6bb9f5h/first_level_analysis/_subject_list_12/selectfiles".
# 210814-22:14:02,851 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:02,871 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:04,729 nipype.workflow INFO:
# 	 [Job 126] Completed (first_level_analysis.selectfiles).
# 210814-22:14:04,733 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 69 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:04,823 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp0xhbgpbe/first_level_analysis/_subject_list_11/selectfiles".
# 210814-22:14:04,829 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:04,841 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:06,731 nipype.workflow INFO:
# 	 [Job 135] Completed (first_level_analysis.selectfiles).
# 210814-22:14:06,737 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 72 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:06,875 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmprj0k5cw2/first_level_analysis/_subject_list_10/selectfiles".
# 210814-22:14:06,891 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:06,908 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:08,731 nipype.workflow INFO:
# 	 [Job 144] Completed (first_level_analysis.selectfiles).
# 210814-22:14:08,739 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 75 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:08,812 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmphy5cibvu/first_level_analysis/_subject_list_09/selectfiles".
# 210814-22:14:08,822 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:08,858 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:10,734 nipype.workflow INFO:
# 	 [Job 153] Completed (first_level_analysis.selectfiles).
# 210814-22:14:10,738 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 78 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:10,805 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpw80h9f9_/first_level_analysis/_subject_list_08/selectfiles".
# 210814-22:14:10,808 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:10,824 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:12,735 nipype.workflow INFO:
# 	 [Job 162] Completed (first_level_analysis.selectfiles).
# 210814-22:14:12,740 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 81 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:12,805 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp68lol2dy/first_level_analysis/_subject_list_07/selectfiles".
# 210814-22:14:12,809 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:12,825 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:14,737 nipype.workflow INFO:
# 	 [Job 171] Completed (first_level_analysis.selectfiles).
# 210814-22:14:14,741 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 84 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:14,807 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp37ual573/first_level_analysis/_subject_list_06/selectfiles".
# 210814-22:14:14,811 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:14,823 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:16,739 nipype.workflow INFO:
# 	 [Job 180] Completed (first_level_analysis.selectfiles).
# 210814-22:14:16,745 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 87 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:16,814 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp6jouv3cd/first_level_analysis/_subject_list_05/selectfiles".
# 210814-22:14:16,820 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:16,830 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:18,741 nipype.workflow INFO:
# 	 [Job 189] Completed (first_level_analysis.selectfiles).
# 210814-22:14:18,747 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 90 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:18,822 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpw61o0uxb/first_level_analysis/_subject_list_04/selectfiles".
# 210814-22:14:18,827 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:18,874 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:20,742 nipype.workflow INFO:
# 	 [Job 198] Completed (first_level_analysis.selectfiles).
# 210814-22:14:20,747 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 93 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:20,836 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmp6own4viv/first_level_analysis/_subject_list_03/selectfiles".
# 210814-22:14:20,851 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:20,869 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:22,743 nipype.workflow INFO:
# 	 [Job 207] Completed (first_level_analysis.selectfiles).
# 210814-22:14:22,750 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 96 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:22,812 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpaj5do30c/first_level_analysis/_subject_list_02/selectfiles".
# 210814-22:14:22,816 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:22,831 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:24,746 nipype.workflow INFO:
# 	 [Job 216] Completed (first_level_analysis.selectfiles).
# 210814-22:14:24,751 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 99 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:24,814 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.selectfiles" in "/tmp/tmpyt0c_og9/first_level_analysis/_subject_list_01/selectfiles".
# 210814-22:14:24,818 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210814-22:14:24,830 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.selectfiles".
# 210814-22:14:26,748 nipype.workflow INFO:
# 	 [Job 225] Completed (first_level_analysis.selectfiles).
# 210814-22:14:26,755 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 102 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:26,823 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmpnvjd6r00/first_level_analysis/_subject_list_26/mask_functional/mapflow/_mask_functional0".
# 210814-22:14:26,828 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/26/smooth/26/smooth_run_1/sub-26_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmpnvjd6r00/first_level_analysis/_subject_list_26/mask_functional/mapflow/_mask_functional0/sub-26_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:14:28,748 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 103 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional0
# 210814-22:14:43,23 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional0".
# 210814-22:14:44,760 nipype.workflow INFO:
# 	 [Job 234] Completed (_mask_functional0).
# 210814-22:14:44,766 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:14:44,824 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmpnvjd6r00/first_level_analysis/_subject_list_26/mask_functional/mapflow/_mask_functional1".
# 210814-22:14:44,829 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional1" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/26/smooth/26/smooth_run_2/sub-26_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmpnvjd6r00/first_level_analysis/_subject_list_26/mask_functional/mapflow/_mask_functional1/sub-26_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:14:46,762 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 102 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional1
# 210814-22:15:00,989 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional1".
# 210814-22:15:02,778 nipype.workflow INFO:
# 	 [Job 235] Completed (_mask_functional1).
# 210814-22:15:02,781 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:02,866 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.mask_functional" in "/tmp/tmpnvjd6r00/first_level_analysis/_subject_list_26/mask_functional".
# 210814-22:15:02,886 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmpnvjd6r00/first_level_analysis/_subject_list_26/mask_functional/mapflow/_mask_functional0".
# 210814-22:15:02,892 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional0" - collecting precomputed outputs
# 210814-22:15:02,894 nipype.workflow INFO:
# 	 [Node] "_mask_functional0" found cached.
# 210814-22:15:02,903 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmpnvjd6r00/first_level_analysis/_subject_list_26/mask_functional/mapflow/_mask_functional1".
# 210814-22:15:02,913 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional1" - collecting precomputed outputs
# 210814-22:15:02,916 nipype.workflow INFO:
# 	 [Node] "_mask_functional1" found cached.
# 210814-22:15:02,925 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.mask_functional".
# 210814-22:15:04,781 nipype.workflow INFO:
# 	 [Job 1] Completed (first_level_analysis.mask_functional).
# 210814-22:15:04,789 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:04,857 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmp2exmjfc5/first_level_analysis/_subject_list_26/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:15:04,863 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo0" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:15:05,258 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo0".
# 210814-22:15:06,786 nipype.workflow INFO:
# 	 [Job 236] Completed (_getsubjectinfo0).
# 210814-22:15:06,790 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:06,877 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmp2exmjfc5/first_level_analysis/_subject_list_26/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:15:06,966 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo1" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:15:07,7 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo1".
# 210814-22:15:08,784 nipype.workflow INFO:
# 	 [Job 237] Completed (_getsubjectinfo1).
# 210814-22:15:08,788 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:08,840 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.getsubjectinfo" in "/tmp/tmp2exmjfc5/first_level_analysis/_subject_list_26/getsubjectinfo".
# 210814-22:15:08,847 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmp2exmjfc5/first_level_analysis/_subject_list_26/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:15:08,850 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo0" - collecting precomputed outputs
# 210814-22:15:08,851 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo0" found cached.
# 210814-22:15:08,854 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmp2exmjfc5/first_level_analysis/_subject_list_26/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:15:08,857 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo1" - collecting precomputed outputs
# 210814-22:15:08,858 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo1" found cached.
# 210814-22:15:08,954 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.getsubjectinfo".
# 210814-22:15:10,786 nipype.workflow INFO:
# 	 [Job 3] Completed (first_level_analysis.getsubjectinfo).
# 210814-22:15:10,792 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:10,871 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmp40sh0bwv/first_level_analysis/_subject_list_25/mask_functional/mapflow/_mask_functional0".
# 210814-22:15:10,880 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/25/smooth/25/smooth_run_1/sub-25_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmp40sh0bwv/first_level_analysis/_subject_list_25/mask_functional/mapflow/_mask_functional0/sub-25_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:15:12,789 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 103 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional0
# 210814-22:15:27,111 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional0".
# 210814-22:15:28,802 nipype.workflow INFO:
# 	 [Job 238] Completed (_mask_functional0).
# 210814-22:15:28,805 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:28,855 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmp40sh0bwv/first_level_analysis/_subject_list_25/mask_functional/mapflow/_mask_functional1".
# 210814-22:15:28,859 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional1" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/25/smooth/25/smooth_run_2/sub-25_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmp40sh0bwv/first_level_analysis/_subject_list_25/mask_functional/mapflow/_mask_functional1/sub-25_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:15:30,804 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 102 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional1
# 210814-22:15:44,789 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional1".
# 210814-22:15:44,820 nipype.workflow INFO:
# 	 [Job 239] Completed (_mask_functional1).
# 210814-22:15:44,826 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:44,891 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.mask_functional" in "/tmp/tmp40sh0bwv/first_level_analysis/_subject_list_25/mask_functional".
# 210814-22:15:44,898 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmp40sh0bwv/first_level_analysis/_subject_list_25/mask_functional/mapflow/_mask_functional0".
# 210814-22:15:44,902 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional0" - collecting precomputed outputs
# 210814-22:15:44,903 nipype.workflow INFO:
# 	 [Node] "_mask_functional0" found cached.
# 210814-22:15:44,908 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmp40sh0bwv/first_level_analysis/_subject_list_25/mask_functional/mapflow/_mask_functional1".
# 210814-22:15:44,911 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional1" - collecting precomputed outputs
# 210814-22:15:44,912 nipype.workflow INFO:
# 	 [Node] "_mask_functional1" found cached.
# 210814-22:15:45,31 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.mask_functional".
# 210814-22:15:46,821 nipype.workflow INFO:
# 	 [Job 10] Completed (first_level_analysis.mask_functional).
# 210814-22:15:46,826 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:46,886 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmpqcstadfs/first_level_analysis/_subject_list_25/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:15:46,890 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo0" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:15:46,930 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo0".
# 210814-22:15:48,823 nipype.workflow INFO:
# 	 [Job 240] Completed (_getsubjectinfo0).
# 210814-22:15:48,826 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:48,879 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmpqcstadfs/first_level_analysis/_subject_list_25/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:15:48,882 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo1" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:15:48,922 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo1".
# 210814-22:15:50,823 nipype.workflow INFO:
# 	 [Job 241] Completed (_getsubjectinfo1).
# 210814-22:15:50,826 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:50,875 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.getsubjectinfo" in "/tmp/tmpqcstadfs/first_level_analysis/_subject_list_25/getsubjectinfo".
# 210814-22:15:50,880 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmpqcstadfs/first_level_analysis/_subject_list_25/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:15:50,883 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo0" - collecting precomputed outputs
# 210814-22:15:50,884 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo0" found cached.
# 210814-22:15:50,886 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmpqcstadfs/first_level_analysis/_subject_list_25/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:15:50,889 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo1" - collecting precomputed outputs
# 210814-22:15:50,890 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo1" found cached.
# 210814-22:15:50,934 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.getsubjectinfo".
# 210814-22:15:52,826 nipype.workflow INFO:
# 	 [Job 12] Completed (first_level_analysis.getsubjectinfo).
# 210814-22:15:52,829 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:15:52,895 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmp62yws90_/first_level_analysis/_subject_list_24/mask_functional/mapflow/_mask_functional0".
# 210814-22:15:52,900 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/24/smooth/24/smooth_run_1/sub-24_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmp62yws90_/first_level_analysis/_subject_list_24/mask_functional/mapflow/_mask_functional0/sub-24_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:15:54,830 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 103 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional0
# 210814-22:16:09,206 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional0".
# 210814-22:16:10,842 nipype.workflow INFO:
# 	 [Job 242] Completed (_mask_functional0).
# 210814-22:16:10,846 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:16:10,898 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmp62yws90_/first_level_analysis/_subject_list_24/mask_functional/mapflow/_mask_functional1".
# 210814-22:16:10,903 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional1" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/24/smooth/24/smooth_run_2/sub-24_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmp62yws90_/first_level_analysis/_subject_list_24/mask_functional/mapflow/_mask_functional1/sub-24_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:16:12,844 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 102 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional1
# 210814-22:16:27,77 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional1".
# 210814-22:16:28,861 nipype.workflow INFO:
# 	 [Job 243] Completed (_mask_functional1).
# 210814-22:16:28,865 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:16:28,922 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.mask_functional" in "/tmp/tmp62yws90_/first_level_analysis/_subject_list_24/mask_functional".
# 210814-22:16:28,934 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmp62yws90_/first_level_analysis/_subject_list_24/mask_functional/mapflow/_mask_functional0".
# 210814-22:16:28,940 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional0" - collecting precomputed outputs
# 210814-22:16:28,941 nipype.workflow INFO:
# 	 [Node] "_mask_functional0" found cached.
# 210814-22:16:28,943 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmp62yws90_/first_level_analysis/_subject_list_24/mask_functional/mapflow/_mask_functional1".
# 210814-22:16:28,947 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional1" - collecting precomputed outputs
# 210814-22:16:28,948 nipype.workflow INFO:
# 	 [Node] "_mask_functional1" found cached.
# 210814-22:16:28,951 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.mask_functional".
# 210814-22:16:30,862 nipype.workflow INFO:
# 	 [Job 19] Completed (first_level_analysis.mask_functional).
# 210814-22:16:30,867 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:16:30,925 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmprx4r6393/first_level_analysis/_subject_list_24/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:16:30,930 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo0" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:16:30,965 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo0".
# 210814-22:16:32,865 nipype.workflow INFO:
# 	 [Job 244] Completed (_getsubjectinfo0).
# 210814-22:16:32,870 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:16:32,932 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmprx4r6393/first_level_analysis/_subject_list_24/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:16:32,971 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo1" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:16:32,991 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo1".
# 210814-22:16:34,868 nipype.workflow INFO:
# 	 [Job 245] Completed (_getsubjectinfo1).
# 210814-22:16:34,873 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:16:34,925 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.getsubjectinfo" in "/tmp/tmprx4r6393/first_level_analysis/_subject_list_24/getsubjectinfo".
# 210814-22:16:34,930 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmprx4r6393/first_level_analysis/_subject_list_24/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:16:34,935 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo0" - collecting precomputed outputs
# 210814-22:16:34,936 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo0" found cached.
# 210814-22:16:34,939 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmprx4r6393/first_level_analysis/_subject_list_24/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:16:34,946 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo1" - collecting precomputed outputs
# 210814-22:16:34,947 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo1" found cached.
# 210814-22:16:34,952 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.getsubjectinfo".
# 210814-22:16:36,870 nipype.workflow INFO:
# 	 [Job 21] Completed (first_level_analysis.getsubjectinfo).
# 210814-22:16:36,877 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:16:36,973 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmpyv3z64im/first_level_analysis/_subject_list_23/mask_functional/mapflow/_mask_functional0".
# 210814-22:16:36,979 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/23/smooth/23/smooth_run_1/sub-23_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmpyv3z64im/first_level_analysis/_subject_list_23/mask_functional/mapflow/_mask_functional0/sub-23_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:16:38,870 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 103 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional0
# 210814-22:16:52,754 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional0".
# 210814-22:16:52,884 nipype.workflow INFO:
# 	 [Job 246] Completed (_mask_functional0).
# 210814-22:16:52,887 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:16:52,945 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmpyv3z64im/first_level_analysis/_subject_list_23/mask_functional/mapflow/_mask_functional1".
# 210814-22:16:52,950 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional1" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/23/smooth/23/smooth_run_2/sub-23_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmpyv3z64im/first_level_analysis/_subject_list_23/mask_functional/mapflow/_mask_functional1/sub-23_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:16:54,886 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 102 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional1
# 210814-22:17:10,260 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional1".
# 210814-22:17:10,901 nipype.workflow INFO:
# 	 [Job 247] Completed (_mask_functional1).
# 210814-22:17:10,904 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:10,958 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.mask_functional" in "/tmp/tmpyv3z64im/first_level_analysis/_subject_list_23/mask_functional".
# 210814-22:17:10,968 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmpyv3z64im/first_level_analysis/_subject_list_23/mask_functional/mapflow/_mask_functional0".
# 210814-22:17:10,972 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional0" - collecting precomputed outputs
# 210814-22:17:10,973 nipype.workflow INFO:
# 	 [Node] "_mask_functional0" found cached.
# 210814-22:17:10,977 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmpyv3z64im/first_level_analysis/_subject_list_23/mask_functional/mapflow/_mask_functional1".
# 210814-22:17:10,980 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional1" - collecting precomputed outputs
# 210814-22:17:10,981 nipype.workflow INFO:
# 	 [Node] "_mask_functional1" found cached.
# 210814-22:17:10,984 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.mask_functional".
# 210814-22:17:12,902 nipype.workflow INFO:
# 	 [Job 28] Completed (first_level_analysis.mask_functional).
# 210814-22:17:12,908 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:12,969 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmpczyycp0l/first_level_analysis/_subject_list_23/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:17:12,974 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo0" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:17:13,20 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo0".
# 210814-22:17:14,903 nipype.workflow INFO:
# 	 [Job 248] Completed (_getsubjectinfo0).
# 210814-22:17:14,906 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:14,962 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmpczyycp0l/first_level_analysis/_subject_list_23/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:17:14,966 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo1" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:17:15,11 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo1".
# 210814-22:17:16,907 nipype.workflow INFO:
# 	 [Job 249] Completed (_getsubjectinfo1).
# 210814-22:17:16,912 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:16,982 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.getsubjectinfo" in "/tmp/tmpczyycp0l/first_level_analysis/_subject_list_23/getsubjectinfo".
# 210814-22:17:16,988 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmpczyycp0l/first_level_analysis/_subject_list_23/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:17:16,991 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo0" - collecting precomputed outputs
# 210814-22:17:16,992 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo0" found cached.
# 210814-22:17:16,995 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmpczyycp0l/first_level_analysis/_subject_list_23/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:17:16,997 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo1" - collecting precomputed outputs
# 210814-22:17:16,998 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo1" found cached.
# 210814-22:17:17,2 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.getsubjectinfo".
# 210814-22:17:18,910 nipype.workflow INFO:
# 	 [Job 30] Completed (first_level_analysis.getsubjectinfo).
# 210814-22:17:18,914 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:18,992 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmpwl_m6jrj/first_level_analysis/_subject_list_22/mask_functional/mapflow/_mask_functional0".
# 210814-22:17:19,1 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/22/smooth/22/smooth_run_1/sub-22_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmpwl_m6jrj/first_level_analysis/_subject_list_22/mask_functional/mapflow/_mask_functional0/sub-22_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:17:20,912 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 103 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional0
# 210814-22:17:35,700 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional0".
# 210814-22:17:36,925 nipype.workflow INFO:
# 	 [Job 250] Completed (_mask_functional0).
# 210814-22:17:36,929 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:36,983 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmpwl_m6jrj/first_level_analysis/_subject_list_22/mask_functional/mapflow/_mask_functional1".
# 210814-22:17:36,988 nipype.workflow INFO:
# 	 [Node] Running "_mask_functional1" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /media/paradeisios/UUI/fmri/flanker/output/preprocessing/22/smooth/22/smooth_run_2/sub-22_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz -mas /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz /tmp/tmpwl_m6jrj/first_level_analysis/_subject_list_22/mask_functional/mapflow/_mask_functional1/sub-22_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth_masked.nii.gz
# 210814-22:17:38,928 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 102 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 0/1.
#                      Currently running:
#                        * _mask_functional1
# 210814-22:17:53,975 nipype.workflow INFO:
# 	 [Node] Finished "_mask_functional1".
# 210814-22:17:54,944 nipype.workflow INFO:
# 	 [Job 251] Completed (_mask_functional1).
# 210814-22:17:54,948 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:55,14 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.mask_functional" in "/tmp/tmpwl_m6jrj/first_level_analysis/_subject_list_22/mask_functional".
# 210814-22:17:55,23 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional0" in "/tmp/tmpwl_m6jrj/first_level_analysis/_subject_list_22/mask_functional/mapflow/_mask_functional0".
# 210814-22:17:55,27 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional0" - collecting precomputed outputs
# 210814-22:17:55,28 nipype.workflow INFO:
# 	 [Node] "_mask_functional0" found cached.
# 210814-22:17:55,32 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_functional1" in "/tmp/tmpwl_m6jrj/first_level_analysis/_subject_list_22/mask_functional/mapflow/_mask_functional1".
# 210814-22:17:55,35 nipype.workflow INFO:
# 	 [Node] Cached "_mask_functional1" - collecting precomputed outputs
# 210814-22:17:55,37 nipype.workflow INFO:
# 	 [Node] "_mask_functional1" found cached.
# 210814-22:17:55,43 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.mask_functional".
# 210814-22:17:56,946 nipype.workflow INFO:
# 	 [Job 37] Completed (first_level_analysis.mask_functional).
# 210814-22:17:56,952 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:57,15 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmp5av0rz7w/first_level_analysis/_subject_list_22/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:17:57,19 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo0" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:17:57,62 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo0".
# 210814-22:17:58,948 nipype.workflow INFO:
# 	 [Job 252] Completed (_getsubjectinfo0).
# 210814-22:17:58,954 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:17:59,16 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmp5av0rz7w/first_level_analysis/_subject_list_22/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:17:59,21 nipype.workflow INFO:
# 	 [Node] Running "_getsubjectinfo1" ("nipype.interfaces.utility.wrappers.Function")
# 210814-22:17:59,56 nipype.workflow INFO:
# 	 [Node] Finished "_getsubjectinfo1".
# 210814-22:18:00,950 nipype.workflow INFO:
# 	 [Job 253] Completed (_getsubjectinfo1).
# 210814-22:18:00,954 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 103 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
# 210814-22:18:01,4 nipype.workflow INFO:
# 	 [Node] Setting-up "first_level_analysis.getsubjectinfo" in "/tmp/tmp5av0rz7w/first_level_analysis/_subject_list_22/getsubjectinfo".
# 210814-22:18:01,9 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo0" in "/tmp/tmp5av0rz7w/first_level_analysis/_subject_list_22/getsubjectinfo/mapflow/_getsubjectinfo0".
# 210814-22:18:01,11 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo0" - collecting precomputed outputs
# 210814-22:18:01,12 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo0" found cached.
# 210814-22:18:01,15 nipype.workflow INFO:
# 	 [Node] Setting-up "_getsubjectinfo1" in "/tmp/tmp5av0rz7w/first_level_analysis/_subject_list_22/getsubjectinfo/mapflow/_getsubjectinfo1".
# 210814-22:18:01,18 nipype.workflow INFO:
# 	 [Node] Cached "_getsubjectinfo1" - collecting precomputed outputs
# 210814-22:18:01,19 nipype.workflow INFO:
# 	 [Node] "_getsubjectinfo1" found cached.
# 210814-22:18:01,23 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.getsubjectinfo".
# 210814-22:18:02,951 nipype.workflow INFO:
# 	 [Job 39] Completed (first_level_analysis.getsubjectinfo).
# 210814-22:18:02,954 nipype.workflow INFO:
# ...
# 210815-01:00:26,242 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/model/_subject_list_01/_modelgen1/run0.png -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/model/01/modelgen_run_2/run0.png
# 210815-01:00:26,246 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/cope1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/cope1.nii.gz
# 210815-01:00:26,262 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/cope2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/cope2.nii.gz
# 210815-01:00:26,275 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/cope3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/cope3.nii.gz
# 210815-01:00:26,288 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/cope4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/cope4.nii.gz
# 210815-01:00:26,304 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/cope5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/cope5.nii.gz
# 210815-01:00:26,322 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/cope6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/cope6.nii.gz
# 210815-01:00:26,335 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/cope1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/cope1.nii.gz
# 210815-01:00:26,349 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/cope2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/cope2.nii.gz
# 210815-01:00:26,362 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/cope3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/cope3.nii.gz
# 210815-01:00:26,374 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/cope4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/cope4.nii.gz
# 210815-01:00:26,391 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/cope5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/cope5.nii.gz
# 210815-01:00:26,404 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/cope6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/cope6.nii.gz
# 210815-01:00:26,418 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/varcope1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/varcope1.nii.gz
# 210815-01:00:26,431 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/varcope2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/varcope2.nii.gz
# 210815-01:00:26,446 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/varcope3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/varcope3.nii.gz
# 210815-01:00:26,463 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/varcope4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/varcope4.nii.gz
# 210815-01:00:26,482 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/varcope5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/varcope5.nii.gz
# 210815-01:00:26,493 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/varcope6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/varcope6.nii.gz
# 210815-01:00:26,507 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/varcope1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/varcope1.nii.gz
# 210815-01:00:26,526 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/varcope2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/varcope2.nii.gz
# 210815-01:00:26,538 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/varcope3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/varcope3.nii.gz
# 210815-01:00:26,555 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/varcope4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/varcope4.nii.gz
# 210815-01:00:26,570 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/varcope5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/varcope5.nii.gz
# 210815-01:00:26,584 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/varcope6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/varcope6.nii.gz
# 210815-01:00:26,607 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/tstat1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/tstat1.nii.gz
# 210815-01:00:26,622 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/tstat2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/tstat2.nii.gz
# 210815-01:00:26,639 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/tstat3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/tstat3.nii.gz
# 210815-01:00:26,651 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/tstat4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/tstat4.nii.gz
# 210815-01:00:26,664 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/tstat5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/tstat5.nii.gz
# 210815-01:00:26,681 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/tstat6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/tstat6.nii.gz
# 210815-01:00:26,699 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/tstat1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/tstat1.nii.gz
# 210815-01:00:26,712 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/tstat2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/tstat2.nii.gz
# 210815-01:00:26,725 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/tstat3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/tstat3.nii.gz
# 210815-01:00:26,739 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/tstat4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/tstat4.nii.gz
# 210815-01:00:26,752 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/tstat5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/tstat5.nii.gz
# 210815-01:00:26,768 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/tstat6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/tstat6.nii.gz
# 210815-01:00:26,785 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/zstat1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/zstat1.nii.gz
# 210815-01:00:26,799 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/zstat2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/zstat2.nii.gz
# 210815-01:00:26,813 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/zstat3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/zstat3.nii.gz
# 210815-01:00:26,828 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/zstat4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/zstat4.nii.gz
# 210815-01:00:26,845 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/zstat5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/zstat5.nii.gz
# 210815-01:00:26,858 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/zstat6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/zstat6.nii.gz
# 210815-01:00:26,876 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/zstat1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/zstat1.nii.gz
# 210815-01:00:26,890 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/zstat2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/zstat2.nii.gz
# 210815-01:00:26,905 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/zstat3.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/zstat3.nii.gz
# 210815-01:00:26,921 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/zstat4.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/zstat4.nii.gz
# 210815-01:00:26,935 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/zstat5.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/zstat5.nii.gz
# 210815-01:00:26,948 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/zstat6.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/zstat6.nii.gz
# 210815-01:00:26,964 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate0/dof -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_1/dof
# 210815-01:00:26,968 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/_subject_list_01/_modelestimate1/dof -> /media/paradeisios/UUI/fmri/flanker/output_without_realign/first_level/modelestimate/01/modelestimate_run_2/dof
# 210815-01:00:26,990 nipype.workflow INFO:
# 	 [Node] Finished "first_level_analysis.datasink".
# 210815-01:00:28,59 nipype.workflow INFO:
# 	 [Job 233] Completed (first_level_analysis.datasink).
# 210815-01:00:28,68 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 1/1.
