# %%
from nipype import Node, Workflow, IdentityInterface, MapNode,SelectFiles, DataSink
from nipype.interfaces import fsl
from nipype.algorithms.rapidart import ArtifactDetect as ART
import numpy as np
import os

# %%
data = "/media/paradeisios/UUI/fmri/flanker/raw"
output = "/media/paradeisios/UUI/fmri/flanker/output/preprocessing"

num_of_subjects = 26
num_of_runs = 2

subject_list = ["{:02d}".format(i) for i in range(1,num_of_subjects+1)]

mni_template = "/home/paradeisios/fsl/data/standard/MNI152_T1_2mm.nii.gz"
mni_brain_template = "/home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz"

TR = 2

# %%
infosource = Node(IdentityInterface(fields=["subject_list"]), name="infosource")
infosource.iterables = [('subject_list', subject_list)]

# %%
templates = {"anat": "sub-{subject_list}/anat/sub-{subject_list}_T1w.nii.gz",
             "func": "sub-{subject_list}/func/sub-{subject_list}_task-flanker_run-*_bold.nii.gz",
             "conditions": "sub-{subject_list}/func/sub-{subject_list}_task-flanker_run-*_events.tsv"}

selectfiles = Node(SelectFiles(templates),name="selectfiles")
selectfiles.inputs.base_directory = data


substitutions = [("_mean_img","mean_img"),
                 ("_subject_list",""),
                 ("_flirt_func","flirt_func"),
                 ("_func_warp","func_warp")]

substitutions += [("_{:02d}".format(i), "{:02d}".format(i)) for i in range(1,num_of_subjects+1)]
substitutions += [("_art{:d}".format(i), "art_run_{:d}".format(i+1)) for i in range(num_of_runs)]
substitutions += [("mean_img{:d}".format(i), "mean_img_run_{:d}".format(i+1)) for i in range(num_of_runs)]
substitutions += [("_realign{:d}".format(i), "realign_{:d}".format(i+1)) for i in range(num_of_runs)]
substitutions += [("flirt_func{:d}".format(i), "flirt_func_run_{:d}".format(i+1)) for i in range(num_of_runs)]
substitutions += [("func_warp{:d}".format(i), "func_warp_run_{:d}".format(i+1)) for i in range(num_of_runs)]
substitutions += [("_smooth{:d}".format(i), "smooth_run_{:d}".format(i+1)) for i in range(num_of_runs)]
substitutions += [("_vol_removal{:d}".format(i), "vol_removal_{:d}".format(i+1)) for i in range(num_of_runs)]

substitutions += [("seg_0", "GM")]
substitutions += [("seg_1", "WM")]
substitutions += [("seg_2", "CSF")]

datasink = Node(DataSink(base_directory=output),name="datasink")
datasink.inputs.substitutions = substitutions
datasink.output = output

# %%
# structural workflow 

bet = Node(fsl.BET(),name="bet")
bet.inputs.frac = 0.3 #value controlling how much of the skull to be removed - increasing might remove bits of brain
bet.inputs.vertical_gradient = 0.2 #value to linearly improve estimations at the bottom of the brain -increasing might understimate top
bet.inputs.mask = True #creates a binary mask of the brain


segment = Node(fsl.FAST(),name="segment")
"""You are interested mainly in the restored version of the structural and
    pve0 = grey matter
    pve1 = white matter
    pve2 = CSF """
segment.inputs.img_type = 1 # indicate its a T1 image
segment.inputs.number_classes = 3 # seperate structural into Grey Matter, White Matter and CSF
segment.inputs.output_biascorrected = True #return structural image bias field corrected
segment.inputs.output_biasfield = True #return bias field
segment.inputs.segments=True #create a binary mask for each tissue type
segment.inputs.no_pve=False #if you dont want partial volume estimation, set to true

flirt_struct = Node(fsl.FLIRT(),name="flirt_struct")
"""This step performs linear registration of the structural volume to the standard space"""
flirt_struct.inputs.reference = mni_brain_template
flirt_struct.inputs.dof = 12 #use 12 dof in structural flirt to prepare image for FNIRT nonlinear normalization to mni space
flirt_struct.inputs.out_matrix_file = "h2s_affine.mat" #keep this to facilite struct and func normalization to mni space using FNIRT
flirt_struct.inputs.interp = "spline" # change to trilinear if you are mostly interested in non-subcortical normalization. Trilinear is faster, but might have some rotational issues
flirt_struct.inputs.cost = "mutualinfo"


fnirt_struct = Node(fsl.FNIRT(),name="fnirt_struct")
"""This step performs non-linear registration of the structural volume to the standard space"""
fnirt_struct.inputs.ref_file = mni_template
fnirt_struct.inputs.config_file = "T1_2_MNI152_2mm"
fnirt_struct.inputs.fieldcoeff_file = True  #keep

# %%
# functional workflow

img_to_float = MapNode(fsl.ImageMaths(),name="img_to_float",iterfield=['in_file'])
"""This converts the 4d in float representation to faciliate some further computations"""
img_to_float.inputs.out_data_type='float'
img_to_float.inputs.op_string=''


vol_removal = MapNode(fsl.ExtractROI(), name="vol_removal",iterfield=['in_file'])
"""This step removes the 5 first volumes to avoid T1 saturation"""
vol_removal.inputs.t_min = 0 #number of scans to exclude from functional image
vol_removal.inputs.t_size = -1 # keep all the rest until the end


realign = MapNode(fsl.MCFLIRT(),name = "realign",iterfield=['in_file'])
"""This step realigns data to the first image"""
realign.inputs.save_mats = True #save realignment  parameters
realign.inputs.save_plots = True #save parameter plots
realign.inputs.dof = 6 #use this for rigid body correction


mean_img = MapNode(fsl.maths.MeanImage(),name= "mean_img",iterfield=['in_file'])
mean_img.inputs.dimension = "T" # find mean image across the time dimension

func_bet = MapNode(fsl.BET(),name= "func_bet",iterfield=['in_file'])
func_bet.inputs.frac = 0.3 #value controlling how much of the skull to be removed - increasing might remove bits of brain
func_bet.inputs.mask = True #creates a binary mask of the brain

art = MapNode(ART(),name="art",iterfield=["mask_file","realigned_files","realignment_parameters"])
art.inputs.mask_type="file"
art.inputs.norm_threshold=1
art.inputs.zintensity_threshold = 3
art.inputs.parameter_source = "FSL"
art.inputs.use_norm=True
art.inputs.use_differences = [True, False]



flirt_func = MapNode(fsl.FLIRT(),name = "flirt_func",iterfield=['in_file'])
"""This step performs linear registration of the functional volume to the structural volume. It is mainly used to
extract the transformation matrix to later register to standard space"""
flirt_func.inputs.dof = 6
flirt_func.inputs.out_matrix_file = "f2h_affine.mat"
flirt_func.inputs.interp = "spline"
flirt_func.inputs.cost = "mutualinfo"


func_warp = MapNode(fsl.ApplyWarp(),name = "func_warp",
                    iterfield=['in_file',"premat"])
"""This step performs non linear registration to standard space using the affine matrix extracted
in the flirt above and the fnirt non linear warp in the structural pipeline """
func_warp.inputs.ref_file = mni_template


smooth = MapNode(fsl.IsotropicSmooth(),name="smooth",iterfield=['in_file'])
"""This step performs smoothing"""
smooth.inputs.fwhm = 6 #change the smoothing kernel

# %%
preprocessing = Workflow(name="preprocessing",base_dir=output)

preprocessing.connect(infosource,"subject_list",selectfiles, "subject_list")
preprocessing.connect(infosource,"subject_list",datasink, "container")                  
preprocessing.connect(selectfiles,"anat",bet, "in_file")  
preprocessing.connect(selectfiles,"anat",fnirt_struct, "in_file") 
                 
preprocessing.connect(bet,"out_file",segment,"in_files")
preprocessing.connect(segment,"restored_image",flirt_struct,"in_file")
preprocessing.connect(flirt_struct,"out_matrix_file",fnirt_struct,"affine_file")

preprocessing.connect(selectfiles,"func",img_to_float, "in_file")   
preprocessing.connect(img_to_float,"out_file",vol_removal,"in_file")
preprocessing.connect(vol_removal, "roi_file", realign, "in_file")
preprocessing.connect(realign, "out_file", mean_img, "in_file")

preprocessing.connect(mean_img, "out_file", func_bet, "in_file")
preprocessing.connect(func_bet, "mask_file", art, "mask_file")
preprocessing.connect(realign, "out_file", art, "realigned_files")
preprocessing.connect(realign, "par_file", art, "realignment_parameters")

preprocessing.connect(mean_img,"out_file",flirt_func,"in_file")
preprocessing.connect(realign,"out_file",func_warp,"in_file")
preprocessing.connect(flirt_func,"out_matrix_file",func_warp,"premat")
preprocessing.connect(segment,"restored_image",flirt_func,"reference")
preprocessing.connect(fnirt_struct,"fieldcoeff_file",func_warp,"field_file")
preprocessing.connect(func_warp,"out_file",smooth,"in_file")

# %%
preprocessing.write_graph(graph2use='flat',format='png', simple_form=True,
                          dotfilename= os.path.join(output,"preprocessing_workflow.dot"))
# Out:
# 210813-00:26:49,875 nipype.workflow INFO:
# 	 Generated workflow graph: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing_workflow.png (graph2use=flat, simple_form=True).
# '/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing_workflow.png'

# %%
preprocessing.connect(selectfiles,"conditions",datasink,"conditions")
preprocessing.connect(bet,"out_file",datasink,"bet.@bet_brain")
preprocessing.connect(bet,"mask_file",datasink,"bet.@bet_mask")
preprocessing.connect(segment,"restored_image",datasink,"segment.@restored_image")
preprocessing.connect(segment,"tissue_class_files",datasink,"segment.@tissue_class_files")
preprocessing.connect(segment,"bias_field",datasink,"segment.@bias_field")
preprocessing.connect(segment,"tissue_class_map",datasink,"segment.@tissue_class_map")
preprocessing.connect(flirt_struct,"out_file",datasink,"flirt_struct.@structural_flirt")
preprocessing.connect(flirt_struct,"out_matrix_file",datasink,"flirt_struct.@affine_parameters")
preprocessing.connect(fnirt_struct,"warped_file",datasink,"flirt_struct.@structural_fnirt")
preprocessing.connect(fnirt_struct,"field_file",datasink,"flirt_struct.@fieldcoeff_file")
preprocessing.connect(vol_removal,"roi_file",datasink,"vol_removal.@files")
preprocessing.connect(realign,"out_file",datasink,"realign.@realigned_files")
preprocessing.connect(realign,"par_file",datasink,"realign.@realig_parameters")
preprocessing.connect(art,"outlier_files",datasink,"art.@art_outliers")
preprocessing.connect(art,"plot_files",datasink,"art.@art_plot")
preprocessing.connect(mean_img,"out_file",datasink,"mean_img.@mean_img")
preprocessing.connect(flirt_func,"out_matrix_file",datasink,"flirt_func.@affine_parameters")
preprocessing.connect(flirt_func,"out_file",datasink,"flirt_func.@functional_flirt")
preprocessing.connect(func_warp,"out_file",datasink,"func_warp.@functional_fnirt")
preprocessing.connect(smooth,"out_file",datasink,"smooth.@smoothed_files")

# %%
preprocessing.run(plugin='MultiProc', plugin_args={'n_procs' : 4})
# Out:
# 210813-00:26:50,76 nipype.workflow INFO:
# 	 Workflow preprocessing settings: ['check', 'execution', 'logging', 'monitoring']
# 210813-00:27:41,363 nipype.workflow INFO:
# 	 Running in parallel.
# 210813-00:27:41,399 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 26 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 4/4.
# 210813-00:27:41,633 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/selectfiles".
# 210813-00:27:41,703 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/selectfiles".
# 210813-00:27:41,741 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/selectfiles".
# 210813-00:27:41,798 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/selectfiles".
# 210813-00:27:41,959 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-00:27:42,19 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-00:27:42,463 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-00:27:42,463 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-00:27:43,174 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-00:27:43,262 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-00:27:43,339 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-00:27:43,373 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-00:27:43,402 nipype.workflow INFO:
# 	 [Job 0] Completed (preprocessing.selectfiles).
# 210813-00:27:43,408 nipype.workflow INFO:
# 	 [Job 15] Completed (preprocessing.selectfiles).
# 210813-00:27:43,410 nipype.workflow INFO:
# 	 [Job 30] Completed (preprocessing.selectfiles).
# 210813-00:27:43,413 nipype.workflow INFO:
# 	 [Job 45] Completed (preprocessing.selectfiles).
# 210813-00:27:43,421 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 30 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 4/4.
# 210813-00:27:43,882 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/bet".
# 210813-00:27:44,274 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/bet".
# 210813-00:27:44,438 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-26/anat/sub-26_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/bet/sub-26_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-00:27:44,688 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/bet".
# 210813-00:27:44,782 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-25/anat/sub-25_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/bet/sub-25_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-00:27:45,27 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/bet".
# 210813-00:27:45,221 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-24/anat/sub-24_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/bet/sub-24_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-00:27:45,401 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.bet
#                        * preprocessing.bet
#                        * preprocessing.bet
#                        * preprocessing.bet
# 210813-00:27:46,258 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-23/anat/sub-23_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/bet/sub-23_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-00:28:04,912 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-00:28:05,434 nipype.workflow INFO:
# 	 [Job 7] Completed (preprocessing.bet).
# 210813-00:28:05,446 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.bet
#                        * preprocessing.bet
#                        * preprocessing.bet
# 210813-00:28:05,578 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-00:28:05,635 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/segment".
# 210813-00:28:05,641 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-00:28:05,672 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/segment/sub-26_T1w_brain.nii.gz
# 210813-00:28:06,970 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-00:28:07,430 nipype.workflow INFO:
# 	 [Job 22] Completed (preprocessing.bet).
# 210813-00:28:07,433 nipype.workflow INFO:
# 	 [Job 37] Completed (preprocessing.bet).
# 210813-00:28:07,438 nipype.workflow INFO:
# 	 [Job 52] Completed (preprocessing.bet).
# 210813-00:28:07,450 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 33 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 3/4.
#                      Currently running:
#                        * preprocessing.segment
# 210813-00:28:07,586 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/segment".
# 210813-00:28:07,588 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/segment".
# 210813-00:28:07,603 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/segment".
# 210813-00:28:07,653 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/segment/sub-24_T1w_brain.nii.gz
# 210813-00:28:07,669 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/segment/sub-25_T1w_brain.nii.gz
# 210813-00:28:07,687 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/segment/sub-23_T1w_brain.nii.gz
# 210813-00:28:09,573 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-00:39:25,282 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-00:39:26,118 nipype.workflow INFO:
# 	 [Job 23] Completed (preprocessing.segment).
# 210813-00:39:26,173 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-00:39:26,371 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/flirt_struct".
# 210813-00:39:26,449 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/segment/sub-25_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-25_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-00:39:28,117 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-00:39:47,496 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-00:39:48,139 nipype.workflow INFO:
# 	 [Job 38] Completed (preprocessing.segment).
# 210813-00:39:48,188 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-00:39:48,357 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/flirt_struct".
# 210813-00:39:48,437 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/segment/sub-24_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-24_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-00:39:50,163 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-00:39:53,591 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-00:39:54,148 nipype.workflow INFO:
# 	 [Job 53] Completed (preprocessing.segment).
# 210813-00:39:54,173 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
# 210813-00:39:54,319 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/flirt_struct".
# 210813-00:39:54,381 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/segment/sub-23_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-23_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-00:39:56,156 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
# 210813-00:39:56,663 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-00:39:58,146 nipype.workflow INFO:
# 	 [Job 8] Completed (preprocessing.segment).
# 210813-00:39:58,168 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:39:58,247 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/flirt_struct".
# 210813-00:39:58,281 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/segment/sub-26_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-26_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-00:40:00,176 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:51:21,454 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.flirt_struct".
# 210813-00:51:22,836 nipype.workflow INFO:
# 	 [Job 25] Completed (preprocessing.flirt_struct).
# 210813-00:51:22,845 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:51:22,923 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.fnirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/fnirt_struct".
# 210813-00:51:23,26 nipype.workflow INFO:
# 	 [Node] Running "fnirt_struct" ("nipype.interfaces.fsl.preprocess.FNIRT"), a CommandLine Interface with command:
# fnirt --aff=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/flirt_struct/h2s_affine.mat --config=T1_2_MNI152_2mm --cout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/fnirt_struct/sub-25_T1w_fieldwarp.nii.gz --in=/media/paradeisios/UUI/fmri/flanker/raw/sub-25/anat/sub-25_T1w.nii.gz --logout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/fnirt_struct/sub-25_T1w_log.txt --ref=/home/paradeisios/fsl/data/standard/MNI152_T1_2mm.nii.gz --iout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_25/fnirt_struct/sub-25_T1w_warped.nii.gz
# 210813-00:51:24,840 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:51:30,73 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.flirt_struct".
# 210813-00:51:30,844 nipype.workflow INFO:
# 	 [Job 40] Completed (preprocessing.flirt_struct).
# 210813-00:51:30,854 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:51:30,924 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.fnirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/fnirt_struct".
# 210813-00:51:31,4 nipype.workflow INFO:
# 	 [Node] Running "fnirt_struct" ("nipype.interfaces.fsl.preprocess.FNIRT"), a CommandLine Interface with command:
# fnirt --aff=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/flirt_struct/h2s_affine.mat --config=T1_2_MNI152_2mm --cout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/fnirt_struct/sub-24_T1w_fieldwarp.nii.gz --in=/media/paradeisios/UUI/fmri/flanker/raw/sub-24/anat/sub-24_T1w.nii.gz --logout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/fnirt_struct/sub-24_T1w_log.txt --ref=/home/paradeisios/fsl/data/standard/MNI152_T1_2mm.nii.gz --iout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_24/fnirt_struct/sub-24_T1w_warped.nii.gz
# 210813-00:51:32,872 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:52:16,469 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.flirt_struct".
# 210813-00:52:16,895 nipype.workflow INFO:
# 	 [Job 55] Completed (preprocessing.flirt_struct).
# 210813-00:52:16,908 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:52:16,978 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.fnirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/fnirt_struct".
# 210813-00:52:17,340 nipype.workflow INFO:
# 	 [Node] Running "fnirt_struct" ("nipype.interfaces.fsl.preprocess.FNIRT"), a CommandLine Interface with command:
# fnirt --aff=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/flirt_struct/h2s_affine.mat --config=T1_2_MNI152_2mm --cout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/fnirt_struct/sub-23_T1w_fieldwarp.nii.gz --in=/media/paradeisios/UUI/fmri/flanker/raw/sub-23/anat/sub-23_T1w.nii.gz --logout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/fnirt_struct/sub-23_T1w_log.txt --ref=/home/paradeisios/fsl/data/standard/MNI152_T1_2mm.nii.gz --iout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_23/fnirt_struct/sub-23_T1w_warped.nii.gz
# 210813-00:52:18,919 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
# 210813-00:53:48,772 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.flirt_struct".
# 210813-00:53:48,992 nipype.workflow INFO:
# 	 [Job 10] Completed (preprocessing.flirt_struct).
# 210813-00:53:49,1 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-00:53:49,77 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.fnirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/fnirt_struct".
# 210813-00:53:49,144 nipype.workflow INFO:
# 	 [Node] Running "fnirt_struct" ("nipype.interfaces.fsl.preprocess.FNIRT"), a CommandLine Interface with command:
# fnirt --aff=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/flirt_struct/h2s_affine.mat --config=T1_2_MNI152_2mm --cout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/fnirt_struct/sub-26_T1w_fieldwarp.nii.gz --in=/media/paradeisios/UUI/fmri/flanker/raw/sub-26/anat/sub-26_T1w.nii.gz --logout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/fnirt_struct/sub-26_T1w_log.txt --ref=/home/paradeisios/fsl/data/standard/MNI152_T1_2mm.nii.gz --iout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_26/fnirt_struct/sub-26_T1w_warped.nii.gz
# 210813-00:53:50,997 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 30 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:09:22,730 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.fnirt_struct".
# 210813-01:09:23,953 nipype.workflow INFO:
# 	 [Job 56] Completed (preprocessing.fnirt_struct).
# 210813-01:09:24,22 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 30 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:09:24,240 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/selectfiles".
# 210813-01:09:24,289 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-01:09:25,951 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 29 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.selectfiles
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:09:27,844 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-01:09:27,951 nipype.workflow INFO:
# 	 [Job 60] Completed (preprocessing.selectfiles).
# 210813-01:09:27,976 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:09:28,109 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/bet".
# 210813-01:09:28,130 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-22/anat/sub-22_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/bet/sub-22_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-01:09:29,976 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 31 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.bet
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:09:39,680 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-01:09:39,962 nipype.workflow INFO:
# 	 [Job 67] Completed (preprocessing.bet).
# 210813-01:09:39,981 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 32 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:09:40,60 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/segment".
# 210813-01:09:40,86 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/segment/sub-22_T1w_brain.nii.gz
# 210813-01:09:42,2 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 31 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:11:28,121 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.fnirt_struct".
# 210813-01:11:30,72 nipype.workflow INFO:
# 	 [Job 26] Completed (preprocessing.fnirt_struct).
# 210813-01:11:30,101 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 31 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:11:30,210 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/selectfiles".
# 210813-01:11:30,233 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-01:11:30,562 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-01:11:32,96 nipype.workflow INFO:
# 	 [Job 75] Completed (preprocessing.selectfiles).
# 210813-01:11:32,159 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 32 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:11:32,636 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/bet".
# 210813-01:11:32,708 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-21/anat/sub-21_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/bet/sub-21_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-01:11:34,81 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 32 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.bet
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
# 210813-01:11:40,166 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.fnirt_struct".
# 210813-01:11:41,439 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-01:11:42,87 nipype.workflow INFO:
# 	 [Job 41] Completed (preprocessing.fnirt_struct).
# 210813-01:11:42,90 nipype.workflow INFO:
# 	 [Job 82] Completed (preprocessing.bet).
# 210813-01:11:42,106 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 33 jobs ready. Free memory (GB): 6.34/6.74, Free processors: 2/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
# 210813-01:11:42,294 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/segment".
# 210813-01:11:42,298 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_20/selectfiles".
# 210813-01:11:42,355 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-01:11:42,366 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/segment/sub-21_T1w_brain.nii.gz
# 210813-01:11:42,413 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-01:11:44,94 nipype.workflow INFO:
# 	 [Job 90] Completed (preprocessing.selectfiles).
# 210813-01:11:44,159 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 33 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
# 210813-01:11:44,426 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_20/bet".
# 210813-01:11:44,484 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-20/anat/sub-20_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_20/bet/sub-20_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-01:11:46,92 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 33 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.bet
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
# 210813-01:11:53,554 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-01:11:54,96 nipype.workflow INFO:
# 	 [Job 97] Completed (preprocessing.bet).
# 210813-01:11:54,119 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 34 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
# 210813-01:11:54,220 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_20/segment".
# 210813-01:11:54,265 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_20/segment/sub-20_T1w_brain.nii.gz
# 210813-01:11:56,136 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 33 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.fnirt_struct
# 210813-01:13:21,327 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.fnirt_struct".
# 210813-01:13:22,193 nipype.workflow INFO:
# 	 [Job 11] Completed (preprocessing.fnirt_struct).
# 210813-01:13:22,258 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 33 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:13:22,437 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.selectfiles" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/selectfiles".
# 210813-01:13:22,469 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 210813-01:13:22,826 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.selectfiles".
# 210813-01:13:24,196 nipype.workflow INFO:
# 	 [Job 105] Completed (preprocessing.selectfiles).
# 210813-01:13:24,263 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 34 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:13:24,488 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.bet" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/bet".
# 210813-01:13:24,539 nipype.workflow INFO:
# 	 [Node] Running "bet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /media/paradeisios/UUI/fmri/flanker/raw/sub-19/anat/sub-19_T1w.nii.gz /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/bet/sub-19_T1w_brain.nii.gz -f 0.30 -m -g 0.20
# 210813-01:13:26,194 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.bet
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:13:31,775 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.bet".
# 210813-01:13:32,198 nipype.workflow INFO:
# 	 [Job 112] Completed (preprocessing.bet).
# 210813-01:13:32,216 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:13:32,288 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.segment" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/segment".
# 210813-01:13:32,318 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -n 3 -B -b -g -S 1 /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/segment/sub-19_T1w_brain.nii.gz
# 210813-01:13:34,225 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:20:54,774 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-01:20:56,672 nipype.workflow INFO:
# 	 [Job 68] Completed (preprocessing.segment).
# 210813-01:20:56,747 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:20:56,913 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/flirt_struct".
# 210813-01:20:56,997 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/segment/sub-22_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-22_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-01:20:58,693 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:23:05,266 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-01:23:06,826 nipype.workflow INFO:
# 	 [Job 83] Completed (preprocessing.segment).
# 210813-01:23:06,891 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:23:07,78 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/flirt_struct".
# 210813-01:23:07,138 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/segment/sub-21_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-21_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-01:23:08,824 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
#                        * preprocessing.segment
# 210813-01:23:50,360 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-01:23:50,880 nipype.workflow INFO:
# 	 [Job 98] Completed (preprocessing.segment).
# 210813-01:23:50,900 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
# 210813-01:23:50,979 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_20/flirt_struct".
# 210813-01:23:51,7 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_20/segment/sub-20_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-20_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-01:23:52,912 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.segment
# 210813-01:24:31,502 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.segment".
# 210813-01:24:32,926 nipype.workflow INFO:
# 	 [Job 113] Completed (preprocessing.segment).
# 210813-01:24:32,995 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-01:24:33,175 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.flirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/flirt_struct".
# 210813-01:24:33,250 nipype.workflow INFO:
# 	 [Node] Running "flirt_struct" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/segment/sub-19_T1w_brain_restore.nii.gz -ref /home/paradeisios/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out sub-19_T1w_brain_restore_flirt.nii.gz -omat h2s_affine.mat -cost mutualinfo -dof 12 -interp spline
# 210813-01:24:34,925 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-01:31:47,482 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.flirt_struct".
# 210813-01:31:49,362 nipype.workflow INFO:
# 	 [Job 70] Completed (preprocessing.flirt_struct).
# 210813-01:31:49,455 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-01:31:49,703 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.fnirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/fnirt_struct".
# 210813-01:31:49,761 nipype.workflow INFO:
# 	 [Node] Running "fnirt_struct" ("nipype.interfaces.fsl.preprocess.FNIRT"), a CommandLine Interface with command:
# fnirt --aff=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/flirt_struct/h2s_affine.mat --config=T1_2_MNI152_2mm --cout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/fnirt_struct/sub-22_T1w_fieldwarp.nii.gz --in=/media/paradeisios/UUI/fmri/flanker/raw/sub-22/anat/sub-22_T1w.nii.gz --logout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/fnirt_struct/sub-22_T1w_log.txt --ref=/home/paradeisios/fsl/data/standard/MNI152_T1_2mm.nii.gz --iout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_22/fnirt_struct/sub-22_T1w_warped.nii.gz
# 210813-01:31:51,360 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-01:35:14,601 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.flirt_struct".
# 210813-01:35:15,562 nipype.workflow INFO:
# 	 [Job 115] Completed (preprocessing.flirt_struct).
# 210813-01:35:15,580 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-01:35:15,673 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.fnirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/fnirt_struct".
# 210813-01:35:15,708 nipype.workflow INFO:
# 	 [Node] Running "fnirt_struct" ("nipype.interfaces.fsl.preprocess.FNIRT"), a CommandLine Interface with command:
# fnirt --aff=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/flirt_struct/h2s_affine.mat --config=T1_2_MNI152_2mm --cout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/fnirt_struct/sub-19_T1w_fieldwarp.nii.gz --in=/media/paradeisios/UUI/fmri/flanker/raw/sub-19/anat/sub-19_T1w.nii.gz --logout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/fnirt_struct/sub-19_T1w_log.txt --ref=/home/paradeisios/fsl/data/standard/MNI152_T1_2mm.nii.gz --iout=/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_19/fnirt_struct/sub-19_T1w_warped.nii.gz
# 210813-01:35:17,566 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 34 jobs ready. Free memory (GB): 5.94/6.74, Free processors: 0/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
#                        * preprocessing.flirt_struct
# 210813-01:35:38,868 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.flirt_struct".
# 210813-01:35:39,584 nipype.workflow INFO:
# 	 [Job 85] Completed (preprocessing.flirt_struct).
# 210813-01:35:39,592 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 35 jobs ready. Free memory (GB): 6.14/6.74, Free processors: 1/4.
#                      Currently running:
#                        * preprocessing.fnirt_struct
#                        * preprocessing.fnirt_struct
#                        * preprocessing.flirt_struct
# 210813-01:35:39,683 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.fnirt_struct" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_21/fnirt_struct".
# 210813-01:35:39,727 nipype.workflow INFO:
# 	 [Node] Running "fnirt_struct" ("nipype.interfaces.fsl.preprocess.FNIRT"), a CommandLine Interface with command:
# ...
# 210813-07:28:32,886 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/art/_subject_list_02/_art1/art.sub-02_task-flanker_run-2_bold_maths_roi_mcf_outliers.txt -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/art/02/art_run_2/art.sub-02_task-flanker_run-2_bold_maths_roi_mcf_outliers.txt
# 210813-07:28:32,892 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/art/_subject_list_02/_art0/plot.sub-02_task-flanker_run-1_bold_maths_roi_mcf.png -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/art/02/art_run_1/plot.sub-02_task-flanker_run-1_bold_maths_roi_mcf.png
# 210813-07:28:32,897 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/art/_subject_list_02/_art1/plot.sub-02_task-flanker_run-2_bold_maths_roi_mcf.png -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/art/02/art_run_2/plot.sub-02_task-flanker_run-2_bold_maths_roi_mcf.png
# 210813-07:28:32,902 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/_subject_list_02/_flirt_func0/f2h_affine.mat -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/02/flirt_func_run_1/f2h_affine.mat
# 210813-07:28:32,919 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/_subject_list_02/_flirt_func1/f2h_affine.mat -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/02/flirt_func_run_2/f2h_affine.mat
# 210813-07:28:32,928 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/_subject_list_02/_flirt_func0/sub-02_task-flanker_run-1_bold_maths_roi_mcf_mean_flirt.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/02/flirt_func_run_1/sub-02_task-flanker_run-1_bold_maths_roi_mcf_mean_flirt.nii.gz
# 210813-07:28:32,937 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/_subject_list_02/_flirt_func1/sub-02_task-flanker_run-2_bold_maths_roi_mcf_mean_flirt.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/flirt_func/02/flirt_func_run_2/sub-02_task-flanker_run-2_bold_maths_roi_mcf_mean_flirt.nii.gz
# 210813-07:28:32,952 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/func_warp/_subject_list_02/_func_warp0/sub-02_task-flanker_run-1_bold_maths_roi_mcf_warp.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/func_warp/02/func_warp_run_1/sub-02_task-flanker_run-1_bold_maths_roi_mcf_warp.nii.gz
# 210813-07:28:32,963 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/func_warp/_subject_list_02/_func_warp1/sub-02_task-flanker_run-2_bold_maths_roi_mcf_warp.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/func_warp/02/func_warp_run_2/sub-02_task-flanker_run-2_bold_maths_roi_mcf_warp.nii.gz
# 210813-07:28:32,973 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/smooth/_subject_list_02/_smooth0/sub-02_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/smooth/02/smooth_run_1/sub-02_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz
# 210813-07:28:32,981 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/smooth/_subject_list_02/_smooth1/sub-02_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/02/smooth/02/smooth_run_2/sub-02_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz
# 210813-07:28:33,28 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.datasink".
# 210813-07:28:33,937 nipype.workflow INFO:
# 	 [Job 374] Completed (preprocessing.datasink).
# 210813-07:28:33,947 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 6.54/6.74, Free processors: 3/4.
#                      Currently running:
#                        * _smooth1
# 210813-07:29:05,454 nipype.workflow INFO:
# 	 [Node] Finished "_smooth1".
# 210813-07:29:05,970 nipype.workflow INFO:
# 	 [Job 857] Completed (_smooth1).
# 210813-07:29:05,975 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 4/4.
# 210813-07:29:06,51 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.smooth" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_01/smooth".
# 210813-07:29:06,81 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth0" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_01/smooth/mapflow/_smooth0".
# 210813-07:29:06,89 nipype.workflow INFO:
# 	 [Node] Cached "_smooth0" - collecting precomputed outputs
# 210813-07:29:06,91 nipype.workflow INFO:
# 	 [Node] "_smooth0" found cached.
# 210813-07:29:06,95 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth1" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_01/smooth/mapflow/_smooth1".
# 210813-07:29:06,109 nipype.workflow INFO:
# 	 [Node] Cached "_smooth1" - collecting precomputed outputs
# 210813-07:29:06,110 nipype.workflow INFO:
# 	 [Node] "_smooth1" found cached.
# 210813-07:29:06,118 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.smooth".
# 210813-07:29:07,971 nipype.workflow INFO:
# 	 [Job 388] Completed (preprocessing.smooth).
# 210813-07:29:07,978 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 4/4.
# 210813-07:29:08,44 nipype.workflow INFO:
# 	 [Node] Setting-up "preprocessing.datasink" in "/media/paradeisios/UUI/fmri/flanker/output/preprocessing/preprocessing/_subject_list_01/datasink".
# 210813-07:29:08,724 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210813-07:29:08,731 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/bet/_subject_list_01/sub-01_T1w_brain.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/bet/01/sub-01_T1w_brain.nii.gz
# 210813-07:29:08,735 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/bet/_subject_list_01/sub-01_T1w_brain_mask.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/bet/01/sub-01_T1w_brain_mask.nii.gz
# 210813-07:29:08,740 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_struct/_subject_list_01/sub-01_T1w_warped.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_struct/01/sub-01_T1w_warped.nii.gz
# 210813-07:29:08,744 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/_subject_list_01/sub-01_T1w_brain_restore.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/01/sub-01_T1w_brain_restore.nii.gz
# 210813-07:29:08,747 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/_subject_list_01/sub-01_T1w_brain_seg_0.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/01/sub-01_T1w_brain_GM.nii.gz
# 210813-07:29:08,751 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/_subject_list_01/sub-01_T1w_brain_seg_1.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/01/sub-01_T1w_brain_WM.nii.gz
# 210813-07:29:08,756 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/_subject_list_01/sub-01_T1w_brain_seg_2.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/01/sub-01_T1w_brain_CSF.nii.gz
# 210813-07:29:08,760 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/_subject_list_01/sub-01_T1w_brain_bias.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/01/sub-01_T1w_brain_bias.nii.gz
# 210813-07:29:08,763 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/_subject_list_01/sub-01_T1w_brain_seg.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/segment/01/sub-01_T1w_brain_seg.nii.gz
# 210813-07:29:08,768 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_struct/_subject_list_01/sub-01_T1w_brain_restore_flirt.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_struct/01/sub-01_T1w_brain_restore_flirt.nii.gz
# 210813-07:29:08,771 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_struct/_subject_list_01/h2s_affine.mat -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_struct/01/h2s_affine.mat
# 210813-07:29:08,774 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/vol_removal/_subject_list_01/_vol_removal0/sub-01_task-flanker_run-1_bold_maths_roi.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/vol_removal/01/vol_removal_1/sub-01_task-flanker_run-1_bold_maths_roi.nii.gz
# 210813-07:29:08,779 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/vol_removal/_subject_list_01/_vol_removal1/sub-01_task-flanker_run-2_bold_maths_roi.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/vol_removal/01/vol_removal_2/sub-01_task-flanker_run-2_bold_maths_roi.nii.gz
# 210813-07:29:08,783 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/_subject_list_01/_realign0/sub-01_task-flanker_run-1_bold_maths_roi_mcf.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/01/realign_1/sub-01_task-flanker_run-1_bold_maths_roi_mcf.nii.gz
# 210813-07:29:08,793 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/_subject_list_01/_realign1/sub-01_task-flanker_run-2_bold_maths_roi_mcf.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/01/realign_2/sub-01_task-flanker_run-2_bold_maths_roi_mcf.nii.gz
# 210813-07:29:08,797 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/_subject_list_01/_realign0/sub-01_task-flanker_run-1_bold_maths_roi_mcf.nii.gz.par -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/01/realign_1/sub-01_task-flanker_run-1_bold_maths_roi_mcf.nii.gz.par
# 210813-07:29:08,802 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/_subject_list_01/_realign1/sub-01_task-flanker_run-2_bold_maths_roi_mcf.nii.gz.par -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/realign/01/realign_2/sub-01_task-flanker_run-2_bold_maths_roi_mcf.nii.gz.par
# 210813-07:29:08,805 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/mean_img/_subject_list_01/_mean_img0/sub-01_task-flanker_run-1_bold_maths_roi_mcf_mean.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/mean_img/01/mean_img_run_1/sub-01_task-flanker_run-1_bold_maths_roi_mcf_mean.nii.gz
# 210813-07:29:08,816 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/mean_img/_subject_list_01/_mean_img1/sub-01_task-flanker_run-2_bold_maths_roi_mcf_mean.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/mean_img/01/mean_img_run_2/sub-01_task-flanker_run-2_bold_maths_roi_mcf_mean.nii.gz
# 210813-07:29:08,824 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/_subject_list_01/_art0/art.sub-01_task-flanker_run-1_bold_maths_roi_mcf_outliers.txt -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/01/art_run_1/art.sub-01_task-flanker_run-1_bold_maths_roi_mcf_outliers.txt
# 210813-07:29:08,829 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/_subject_list_01/_art1/art.sub-01_task-flanker_run-2_bold_maths_roi_mcf_outliers.txt -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/01/art_run_2/art.sub-01_task-flanker_run-2_bold_maths_roi_mcf_outliers.txt
# 210813-07:29:08,834 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/_subject_list_01/_art0/plot.sub-01_task-flanker_run-1_bold_maths_roi_mcf.png -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/01/art_run_1/plot.sub-01_task-flanker_run-1_bold_maths_roi_mcf.png
# 210813-07:29:08,837 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/_subject_list_01/_art1/plot.sub-01_task-flanker_run-2_bold_maths_roi_mcf.png -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/art/01/art_run_2/plot.sub-01_task-flanker_run-2_bold_maths_roi_mcf.png
# 210813-07:29:08,845 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/_subject_list_01/_flirt_func0/f2h_affine.mat -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/01/flirt_func_run_1/f2h_affine.mat
# 210813-07:29:08,851 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/_subject_list_01/_flirt_func1/f2h_affine.mat -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/01/flirt_func_run_2/f2h_affine.mat
# 210813-07:29:08,854 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/_subject_list_01/_flirt_func0/sub-01_task-flanker_run-1_bold_maths_roi_mcf_mean_flirt.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/01/flirt_func_run_1/sub-01_task-flanker_run-1_bold_maths_roi_mcf_mean_flirt.nii.gz
# 210813-07:29:08,857 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/_subject_list_01/_flirt_func1/sub-01_task-flanker_run-2_bold_maths_roi_mcf_mean_flirt.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/flirt_func/01/flirt_func_run_2/sub-01_task-flanker_run-2_bold_maths_roi_mcf_mean_flirt.nii.gz
# 210813-07:29:08,860 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/func_warp/_subject_list_01/_func_warp0/sub-01_task-flanker_run-1_bold_maths_roi_mcf_warp.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/func_warp/01/func_warp_run_1/sub-01_task-flanker_run-1_bold_maths_roi_mcf_warp.nii.gz
# 210813-07:29:08,864 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/func_warp/_subject_list_01/_func_warp1/sub-01_task-flanker_run-2_bold_maths_roi_mcf_warp.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/func_warp/01/func_warp_run_2/sub-01_task-flanker_run-2_bold_maths_roi_mcf_warp.nii.gz
# 210813-07:29:08,868 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/smooth/_subject_list_01/_smooth0/sub-01_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/smooth/01/smooth_run_1/sub-01_task-flanker_run-1_bold_maths_roi_mcf_warp_smooth.nii.gz
# 210813-07:29:08,872 nipype.interface INFO:
# 	 sub: /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/smooth/_subject_list_01/_smooth1/sub-01_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz -> /media/paradeisios/UUI/fmri/flanker/output/preprocessing/01/smooth/01/smooth_run_2/sub-01_task-flanker_run-2_bold_maths_roi_mcf_warp_smooth.nii.gz
# 210813-07:29:08,890 nipype.workflow INFO:
# 	 [Node] Finished "preprocessing.datasink".
# 210813-07:29:09,974 nipype.workflow INFO:
# 	 [Job 389] Completed (preprocessing.datasink).
# 210813-07:29:09,979 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.74/6.74, Free processors: 4/4.
